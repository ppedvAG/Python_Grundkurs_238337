# %% [markdown]
# ## Eigene Umgebung

# %% [markdown]
# Wieder ein paar Begriffe:
#
# Spaces:
# - Box
#     - Bereich zwischen 2 Zahlen
#
# - Discrete
#     - Liste mit Werten von 0 bis Maximum
#
# - Tuple
#     - Kombiniert mehrere Spaces zusammen
#
# - Dict
#     - Benanntes Tupel

# %%
import gymnasium as gym
import numpy as np
import gymnasium.spaces as sp
from typing import Optional

# %%
disc = sp.Discrete(3)

# %%
for x in range(100):
    print(disc.sample())
# Out:
# 2
# 1
# 1
# 1
# 0
# 2
# 0
# 2
# 2
# 1
# 0
# 2
# 0
# 2
# 1
# 2
# 0
# 1
# 2
# 1
# 2
# 2
# 1
# 2
# 1
# 1
# 2
# 1
# 0
# 1
# 1
# 1
# 1
# 1
# 0
# 2
# 1
# 0
# 0
# 2
# 2
# 0
# 0
# 1
# 0
# 1
# 2
# 1
# 1
# 1
# 1
# 0
# 0
# 0
# 1
# 2
# 0
# 1
# 0
# 1
# 1
# 2
# 0
# 1
# 1
# 1
# 1
# 1
# 0
# 2
# 0
# 0
# 0
# 2
# 2
# 0
# 0
# 0
# 1
# 0
# 1
# 1
# 1
# 2
# 1
# 2
# 1
# 0
# 1
# 2
# 2
# 1
# 1
# 1
# 1
# 1
# 1
# 0
# 2
# 1

# %%
box = sp.Box(0, 100)

# %%
box.sample()
# Out:
# array([86.630585], dtype=float32)

# %%
boxShape = sp.Box(0, 100, shape=(3, 3))

# %%
boxShape.sample()
# Out:
# array([[26.525356, 34.17661 , 11.240754],
#        [60.992878, 16.596964, 45.657505],
#        [67.25015 , 85.00008 , 24.594597]], dtype=float32)

# %%
sp.Tuple((sp.Discrete(3), sp.Discrete(3)))
# Out:
# Tuple(Discrete(3), Discrete(3))

# %%
sp.Dict({"X": sp.Box(0, 10), "Y": sp.Box(0, 5)})
# Out:
# OrderedDict([('X', array([5.20383], dtype=float32)),
#              ('Y', array([2.9084616], dtype=float32))])

# %% [markdown]
# ## Eigene Umgebung
#
# Muss eine Klasse sein die von gym.Env erbt
#
# Dadurch müssen die Funktionen step() und reset() implementiert werden
#
# - Observation Space: Die Daten die beobachtet werden (der State nach einem Step)
# - Action Space: Die möglichen Aktionen des Agenten (z.B. Links, Rechts)
# - State: Der derzeitige Status

# %%
class CarDriver(gym.Env):
    def __init__(self):
        self.action_space = sp.Discrete(3)  # Die verschiedenen Aktionen: Bremsen, Beschleunigen, Nix tun
        self.observation_space = sp.Box(0, 100, dtype=np.int8)  # Die Geschwindigkeit zwischen 0 und 100
        self.state = 40 + np.random.randint(0, 10)  # Startgeschwindigkeit
        self.drive_length = 60  # Länge der Fahrt
        
    def step(self, action):
        # Action verwendet
        # 0: Nix (+0km/h)
        # 1: Bremsen (-3km/h)
        # 2: Beschleunigen (+3km/h)
        if action == 1:
            self.state -= 3
        if action == 2:
            self.state += 3

        # Belohnung berechnen
        # Zwischen 45 und 55 km/h -> +1 Punkt sonst -1 Punkt
        if self.state >= 45 and self.state <= 55:
            reward = 1
        else:
            reward = -1

        # Noise
        self.state += np.random.randint(-1, 1)

        self.drive_length -= 1
        
        # State muss bei return immer ein Numpy Array sein
        return np.array([self.state], dtype=np.int8), reward, self.drive_length == 0, False, {}

    def reset(self, *, seed: Optional[int] = None, options: Optional[dict] = None,):
        self.state = 40 + np.random.randint(0, 10)  # Startgeschwindigkeit
        self.drive_length = 60  # Länge der Fahrt
        return (np.array([self.state], dtype=np.int8), {})

# %%
from stable_baselines3.common.env_checker import check_env
from stable_baselines3 import PPO

# %%
env = CarDriver()

# %%
check_env(env, warn=True)

# %%
durchgaenge = 5
for x in range(durchgaenge):
    state = env.reset()  # Gibt den Startstate zurück
    score = 0  # Score sollte 200 erreichen

    while True:
        # env.render()
        action = env.action_space.sample()  # Random Action auswählen
        new_state, reward, done, term, info = env.step(action)  # Action an die Umgebung weitergeben
        score += reward
        if done or term:
            break

    print(f"Durchgang {x}: Score: {score}")
# Out:
# Durchgang 0: Score: -60
# Durchgang 1: Score: -56
# Durchgang 2: Score: -38
# Durchgang 3: Score: -54
# Durchgang 4: Score: -60

# %%
model = PPO("MlpPolicy", env, verbose=1)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
model.learn(total_timesteps=100000)
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 23       |
# | time/              |          |
# |    fps             | 876      |
# |    iterations      | 1        |
# |    time_elapsed    | 2        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 25.6        |
# | time/                   |             |
# |    fps                  | 525         |
# |    iterations           | 2           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008383241 |
# |    clip_fraction        | 0.158       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | 0.0243      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 15.4        |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00907    |
# |    value_loss           | 33.4        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 31           |
# | time/                   |              |
# |    fps                  | 451          |
# |    iterations           | 3            |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0077821217 |
# |    clip_fraction        | 0.141        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.03        |
# |    explained_variance   | 0.0265       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 11.2         |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.0113      |
# |    value_loss           | 37.4         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 36          |
# | time/                   |             |
# |    fps                  | 425         |
# |    iterations           | 4           |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.008151637 |
# |    clip_fraction        | 0.0981      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.996      |
# |    explained_variance   | 0.00512     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 16.1        |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00166    |
# |    value_loss           | 40.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 37.9        |
# | time/                   |             |
# |    fps                  | 416         |
# |    iterations           | 5           |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.008888319 |
# |    clip_fraction        | 0.12        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.974      |
# |    explained_variance   | 0.00048     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 23.7        |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00162    |
# |    value_loss           | 45.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 38.6        |
# | time/                   |             |
# |    fps                  | 397         |
# |    iterations           | 6           |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.010777013 |
# |    clip_fraction        | 0.203       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.989      |
# |    explained_variance   | -0.00021    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 28.5        |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0139     |
# |    value_loss           | 56.6        |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 60        |
# |    ep_rew_mean          | 40.6      |
# | time/                   |           |
# |    fps                  | 397       |
# |    iterations           | 7         |
# |    time_elapsed         | 36        |
# |    total_timesteps      | 14336     |
# | train/                  |           |
# |    approx_kl            | 0.0102343 |
# |    clip_fraction        | 0.109     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.988    |
# |    explained_variance   | 7.65e-05  |
# |    learning_rate        | 0.0003    |
# |    loss                 | 27.7      |
# |    n_updates            | 160       |
# |    policy_gradient_loss | -0.00371  |
# |    value_loss           | 56.7      |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 45          |
# | time/                   |             |
# |    fps                  | 398         |
# |    iterations           | 8           |
# |    time_elapsed         | 41          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.015597869 |
# |    clip_fraction        | 0.125       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.977      |
# |    explained_variance   | -1.75e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 24          |
# |    n_updates            | 170         |
# |    policy_gradient_loss | 0.000844    |
# |    value_loss           | 60.8        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 44.5         |
# | time/                   |              |
# |    fps                  | 398          |
# |    iterations           | 9            |
# |    time_elapsed         | 46           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0066424264 |
# |    clip_fraction        | 0.136        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.975       |
# |    explained_variance   | -4.3e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 42.7         |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.002       |
# |    value_loss           | 67.2         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 46.1         |
# | time/                   |              |
# |    fps                  | 386          |
# |    iterations           | 10           |
# |    time_elapsed         | 53           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0075254296 |
# |    clip_fraction        | 0.134        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.978       |
# |    explained_variance   | -1.86e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 33.3         |
# |    n_updates            | 190          |
# |    policy_gradient_loss | 0.000671     |
# |    value_loss           | 70.2         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 47.4        |
# | time/                   |             |
# |    fps                  | 386         |
# |    iterations           | 11          |
# |    time_elapsed         | 58          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.006624465 |
# |    clip_fraction        | 0.156       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.949      |
# |    explained_variance   | -7.99e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 33.4        |
# |    n_updates            | 200         |
# |    policy_gradient_loss | 0.00463     |
# |    value_loss           | 71.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 50.4        |
# | time/                   |             |
# |    fps                  | 387         |
# |    iterations           | 12          |
# |    time_elapsed         | 63          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.014238706 |
# |    clip_fraction        | 0.135       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.956      |
# |    explained_variance   | -1.26e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 48.1        |
# |    n_updates            | 210         |
# |    policy_gradient_loss | 0.00377     |
# |    value_loss           | 81.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 51.5        |
# | time/                   |             |
# |    fps                  | 387         |
# |    iterations           | 13          |
# |    time_elapsed         | 68          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.011526221 |
# |    clip_fraction        | 0.132       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.932      |
# |    explained_variance   | -8.94e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 38.3        |
# |    n_updates            | 220         |
# |    policy_gradient_loss | 0.00328     |
# |    value_loss           | 87.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 50.6        |
# | time/                   |             |
# |    fps                  | 389         |
# |    iterations           | 14          |
# |    time_elapsed         | 73          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.016122976 |
# |    clip_fraction        | 0.136       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.947      |
# |    explained_variance   | -4.05e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 61.7        |
# |    n_updates            | 230         |
# |    policy_gradient_loss | 0.00466     |
# |    value_loss           | 90.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 49.8        |
# | time/                   |             |
# |    fps                  | 384         |
# |    iterations           | 15          |
# |    time_elapsed         | 79          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.011765091 |
# |    clip_fraction        | 0.176       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.929      |
# |    explained_variance   | -1.07e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 53.8        |
# |    n_updates            | 240         |
# |    policy_gradient_loss | 0.00728     |
# |    value_loss           | 91.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 49          |
# | time/                   |             |
# |    fps                  | 383         |
# |    iterations           | 16          |
# |    time_elapsed         | 85          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.010801546 |
# |    clip_fraction        | 0.143       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.945      |
# |    explained_variance   | 2.86e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 57.5        |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00116    |
# |    value_loss           | 92.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 50.3        |
# | time/                   |             |
# |    fps                  | 382         |
# |    iterations           | 17          |
# |    time_elapsed         | 91          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.008317263 |
# |    clip_fraction        | 0.172       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.945      |
# |    explained_variance   | -3.58e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 46.7        |
# |    n_updates            | 260         |
# |    policy_gradient_loss | 0.00763     |
# |    value_loss           | 89.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 52          |
# | time/                   |             |
# |    fps                  | 381         |
# |    iterations           | 18          |
# |    time_elapsed         | 96          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.012521914 |
# |    clip_fraction        | 0.162       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.917      |
# |    explained_variance   | -2.15e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 44.1        |
# |    n_updates            | 270         |
# |    policy_gradient_loss | 0.00298     |
# |    value_loss           | 92.1        |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 60        |
# |    ep_rew_mean          | 52.7      |
# | time/                   |           |
# |    fps                  | 379       |
# |    iterations           | 19        |
# |    time_elapsed         | 102       |
# |    total_timesteps      | 38912     |
# | train/                  |           |
# |    approx_kl            | 0.0079674 |
# |    clip_fraction        | 0.186     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.94     |
# |    explained_variance   | -2.74e-06 |
# |    learning_rate        | 0.0003    |
# |    loss                 | 59.3      |
# |    n_updates            | 280       |
# |    policy_gradient_loss | 0.00457   |
# |    value_loss           | 96.8      |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 53.6        |
# | time/                   |             |
# |    fps                  | 374         |
# |    iterations           | 20          |
# |    time_elapsed         | 109         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.007808074 |
# |    clip_fraction        | 0.143       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.926      |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 51.2        |
# |    n_updates            | 290         |
# |    policy_gradient_loss | 0.0034      |
# |    value_loss           | 98.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 54.2        |
# | time/                   |             |
# |    fps                  | 366         |
# |    iterations           | 21          |
# |    time_elapsed         | 117         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.011122995 |
# |    clip_fraction        | 0.146       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.913      |
# |    explained_variance   | -1.19e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 52.6        |
# |    n_updates            | 300         |
# |    policy_gradient_loss | 0.00215     |
# |    value_loss           | 101         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 55.1        |
# | time/                   |             |
# |    fps                  | 368         |
# |    iterations           | 22          |
# |    time_elapsed         | 122         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.007174194 |
# |    clip_fraction        | 0.156       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.926      |
# |    explained_variance   | -1.67e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 41.7        |
# |    n_updates            | 310         |
# |    policy_gradient_loss | 0.00317     |
# |    value_loss           | 104         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | 55.4       |
# | time/                   |            |
# |    fps                  | 369        |
# |    iterations           | 23         |
# |    time_elapsed         | 127        |
# |    total_timesteps      | 47104      |
# | train/                  |            |
# |    approx_kl            | 0.03051391 |
# |    clip_fraction        | 0.159      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.926     |
# |    explained_variance   | -5.48e-06  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 39.3       |
# |    n_updates            | 320        |
# |    policy_gradient_loss | 0.00204    |
# |    value_loss           | 107        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 55.4        |
# | time/                   |             |
# |    fps                  | 370         |
# |    iterations           | 24          |
# |    time_elapsed         | 132         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.009299897 |
# |    clip_fraction        | 0.157       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.926      |
# |    explained_variance   | -1.19e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 40.7        |
# |    n_updates            | 330         |
# |    policy_gradient_loss | 0.00487     |
# |    value_loss           | 107         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 54.5        |
# | time/                   |             |
# |    fps                  | 370         |
# |    iterations           | 25          |
# |    time_elapsed         | 138         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.012002275 |
# |    clip_fraction        | 0.157       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.922      |
# |    explained_variance   | -4.77e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 35.7        |
# |    n_updates            | 340         |
# |    policy_gradient_loss | 0.00715     |
# |    value_loss           | 108         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 54.3        |
# | time/                   |             |
# |    fps                  | 371         |
# |    iterations           | 26          |
# |    time_elapsed         | 143         |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.021242991 |
# |    clip_fraction        | 0.139       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.907      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 45.1        |
# |    n_updates            | 350         |
# |    policy_gradient_loss | 0.00263     |
# |    value_loss           | 107         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 54.3        |
# | time/                   |             |
# |    fps                  | 371         |
# |    iterations           | 27          |
# |    time_elapsed         | 148         |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.021283297 |
# |    clip_fraction        | 0.114       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.918      |
# |    explained_variance   | -1.43e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 63.3        |
# |    n_updates            | 360         |
# |    policy_gradient_loss | 0.00273     |
# |    value_loss           | 105         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 55.1        |
# | time/                   |             |
# |    fps                  | 368         |
# |    iterations           | 28          |
# |    time_elapsed         | 155         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.009254478 |
# |    clip_fraction        | 0.167       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.918      |
# |    explained_variance   | -1.19e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 73.4        |
# |    n_updates            | 370         |
# |    policy_gradient_loss | 0.00721     |
# |    value_loss           | 105         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 55.1        |
# | time/                   |             |
# |    fps                  | 367         |
# |    iterations           | 29          |
# |    time_elapsed         | 161         |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.009064946 |
# |    clip_fraction        | 0.182       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.917      |
# |    explained_variance   | -2.38e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 33.1        |
# |    n_updates            | 380         |
# |    policy_gradient_loss | 0.00631     |
# |    value_loss           | 106         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 55.4        |
# | time/                   |             |
# |    fps                  | 368         |
# |    iterations           | 30          |
# |    time_elapsed         | 166         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.006564148 |
# |    clip_fraction        | 0.159       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.919      |
# |    explained_variance   | -4.77e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 58.7        |
# |    n_updates            | 390         |
# |    policy_gradient_loss | 0.00573     |
# |    value_loss           | 109         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 55.9        |
# | time/                   |             |
# |    fps                  | 369         |
# |    iterations           | 31          |
# |    time_elapsed         | 171         |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.010688862 |
# |    clip_fraction        | 0.137       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.918      |
# |    explained_variance   | -4.77e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 49.8        |
# |    n_updates            | 400         |
# |    policy_gradient_loss | 0.00213     |
# |    value_loss           | 110         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 55.3        |
# | time/                   |             |
# |    fps                  | 371         |
# |    iterations           | 32          |
# |    time_elapsed         | 176         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.015242174 |
# |    clip_fraction        | 0.147       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.909      |
# |    explained_variance   | -2.38e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 63.8        |
# |    n_updates            | 410         |
# |    policy_gradient_loss | 0.00554     |
# |    value_loss           | 113         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 54.1        |
# | time/                   |             |
# |    fps                  | 372         |
# |    iterations           | 33          |
# |    time_elapsed         | 181         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.012391189 |
# |    clip_fraction        | 0.14        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.9        |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 79.3        |
# |    n_updates            | 420         |
# |    policy_gradient_loss | 0.00158     |
# |    value_loss           | 107         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 53.1        |
# | time/                   |             |
# |    fps                  | 373         |
# |    iterations           | 34          |
# |    time_elapsed         | 186         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.014066694 |
# |    clip_fraction        | 0.105       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.894      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 39.8        |
# |    n_updates            | 430         |
# |    policy_gradient_loss | 0.00225     |
# |    value_loss           | 106         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 53.6         |
# | time/                   |              |
# |    fps                  | 373          |
# |    iterations           | 35           |
# |    time_elapsed         | 191          |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0063565117 |
# |    clip_fraction        | 0.149        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.897       |
# |    explained_variance   | 1.79e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 47.4         |
# |    n_updates            | 440          |
# |    policy_gradient_loss | 0.00567      |
# |    value_loss           | 102          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 55          |
# | time/                   |             |
# |    fps                  | 374         |
# |    iterations           | 36          |
# |    time_elapsed         | 197         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.010018675 |
# |    clip_fraction        | 0.188       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.877      |
# |    explained_variance   | 4.17e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 69          |
# |    n_updates            | 450         |
# |    policy_gradient_loss | 0.0101      |
# |    value_loss           | 106         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 56.6         |
# | time/                   |              |
# |    fps                  | 374          |
# |    iterations           | 37           |
# |    time_elapsed         | 202          |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0077042975 |
# |    clip_fraction        | 0.173        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.862       |
# |    explained_variance   | 4.17e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 62.6         |
# |    n_updates            | 460          |
# |    policy_gradient_loss | 0.0079       |
# |    value_loss           | 108          |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | 57.3       |
# | time/                   |            |
# |    fps                  | 375        |
# |    iterations           | 38         |
# |    time_elapsed         | 207        |
# |    total_timesteps      | 77824      |
# | train/                  |            |
# |    approx_kl            | 0.00669644 |
# |    clip_fraction        | 0.162      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.871     |
# |    explained_variance   | 1.19e-07   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 57.8       |
# |    n_updates            | 470        |
# |    policy_gradient_loss | 0.0049     |
# |    value_loss           | 113        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 57.2        |
# | time/                   |             |
# |    fps                  | 376         |
# |    iterations           | 39          |
# |    time_elapsed         | 212         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.014254106 |
# |    clip_fraction        | 0.122       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.86       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 46.1        |
# |    n_updates            | 480         |
# |    policy_gradient_loss | 0.00252     |
# |    value_loss           | 115         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 56.7        |
# | time/                   |             |
# |    fps                  | 377         |
# |    iterations           | 40          |
# |    time_elapsed         | 217         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.008811751 |
# |    clip_fraction        | 0.162       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.881      |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 44.3        |
# |    n_updates            | 490         |
# |    policy_gradient_loss | 0.00816     |
# |    value_loss           | 114         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 56.4        |
# | time/                   |             |
# |    fps                  | 378         |
# |    iterations           | 41          |
# |    time_elapsed         | 221         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.006841153 |
# |    clip_fraction        | 0.123       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.858      |
# |    explained_variance   | 4.17e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 59.1        |
# |    n_updates            | 500         |
# |    policy_gradient_loss | 0.00297     |
# |    value_loss           | 113         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 56.2        |
# | time/                   |             |
# |    fps                  | 378         |
# |    iterations           | 42          |
# |    time_elapsed         | 227         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.010885119 |
# |    clip_fraction        | 0.118       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.87       |
# |    explained_variance   | 3.22e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 54.8        |
# |    n_updates            | 510         |
# |    policy_gradient_loss | 0.00151     |
# |    value_loss           | 114         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 56.2        |
# | time/                   |             |
# |    fps                  | 378         |
# |    iterations           | 43          |
# |    time_elapsed         | 232         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.006021086 |
# |    clip_fraction        | 0.141       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.862      |
# |    explained_variance   | 6.91e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 62.2        |
# |    n_updates            | 520         |
# |    policy_gradient_loss | 0.00498     |
# |    value_loss           | 112         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 56.1        |
# | time/                   |             |
# |    fps                  | 379         |
# |    iterations           | 44          |
# |    time_elapsed         | 237         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.005854074 |
# |    clip_fraction        | 0.123       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.852      |
# |    explained_variance   | 3.68e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 55          |
# |    n_updates            | 530         |
# |    policy_gradient_loss | 0.00168     |
# |    value_loss           | 112         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 55.9        |
# | time/                   |             |
# |    fps                  | 379         |
# |    iterations           | 45          |
# |    time_elapsed         | 242         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.006720513 |
# |    clip_fraction        | 0.116       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.845      |
# |    explained_variance   | 8.42e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 65          |
# |    n_updates            | 540         |
# |    policy_gradient_loss | 0.00189     |
# |    value_loss           | 114         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 55.2         |
# | time/                   |              |
# |    fps                  | 380          |
# |    iterations           | 46           |
# |    time_elapsed         | 247          |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0044181775 |
# |    clip_fraction        | 0.132        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.858       |
# |    explained_variance   | 0.000427     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 67.2         |
# |    n_updates            | 550          |
# |    policy_gradient_loss | 0.00289      |
# |    value_loss           | 115          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 53.7         |
# | time/                   |              |
# |    fps                  | 380          |
# |    iterations           | 47           |
# |    time_elapsed         | 253          |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0064667473 |
# |    clip_fraction        | 0.147        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.857       |
# |    explained_variance   | 0.000778     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 57.3         |
# |    n_updates            | 560          |
# |    policy_gradient_loss | 0.00524      |
# |    value_loss           | 107          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 51.2        |
# | time/                   |             |
# |    fps                  | 380         |
# |    iterations           | 48          |
# |    time_elapsed         | 258         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.007732153 |
# |    clip_fraction        | 0.131       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.858      |
# |    explained_variance   | 0.001       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 47.5        |
# |    n_updates            | 570         |
# |    policy_gradient_loss | 0.00509     |
# |    value_loss           | 102         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 49.3        |
# | time/                   |             |
# |    fps                  | 380         |
# |    iterations           | 49          |
# |    time_elapsed         | 263         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.014172861 |
# |    clip_fraction        | 0.142       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.852      |
# |    explained_variance   | 0.0013      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 32.6        |
# |    n_updates            | 580         |
# |    policy_gradient_loss | 0.00321     |
# |    value_loss           | 95.2        |
# -----------------------------------------

# %%
model.save("CarDriver.zip")

# %%
env = CarDriver()

# %%
model.load("CarDriver.zip", env)
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
durchgaenge = 20
for x in range(durchgaenge):
    state = env.reset()  # Gibt den Startstate zurück
    score = 0  # Score sollte 60 erreichen

    while True:
        # env.render()
        if len(state) == 2:
            action = model.predict(state[0])  # Random Action auswählen
        else:
            action = model.predict(state)
        state, reward, done, term, info = env.step(action[0])  # Action an die Umgebung weitergeben
        score += reward
        if done or term:
            break

    print(f"Barl Kenz {x}: Score: {score}")
# Out:
# Barl Kenz 0: Score: 60
# Barl Kenz 1: Score: 54
# Barl Kenz 2: Score: 60
# Barl Kenz 3: Score: 58
# Barl Kenz 4: Score: 56
# Barl Kenz 5: Score: 52
# Barl Kenz 6: Score: 48
# Barl Kenz 7: Score: 56
# Barl Kenz 8: Score: 58
# Barl Kenz 9: Score: 54
# Barl Kenz 10: Score: 54
# Barl Kenz 11: Score: 60
# Barl Kenz 12: Score: 60
# Barl Kenz 13: Score: 60
# Barl Kenz 14: Score: 54
# Barl Kenz 15: Score: 60
# Barl Kenz 16: Score: 60
# Barl Kenz 17: Score: 54
# Barl Kenz 18: Score: 52
# Barl Kenz 19: Score: 58
